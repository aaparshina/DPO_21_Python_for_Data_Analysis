# %% [markdown]
# # Python для автоматизации и анализа данных
#
# ## Домашнее задание 1 (дедлайн: 3 ноября 2021 23:59 (мск))
#
# *Если работа сдается после дедлайна, то за каждый день просрочки отнимается 1 балл (из 10 максимально возможных)*
#
# **Загружать работу на дропбокс: https://www.dropbox.com/request/axn2cGw1REhI2cn2J4LS** в виде `ipynb`-файла. Получить `ipynb`-файл можно, выбрав в Jupyter пункт меню *File → Download as... → IPython Notebook (.ipynb)*.
#
# *Материалы взяты из курсов Тамбовцевой Аллы «Основы программирования в Python» и Рогович Татьяны «Python для исследователей».*
#
# *Задача 7 заимствована из [домашнего задания](http://nbviewer.jupyter.org/url/python.math-hse.info/static/assignments_release/dj2017/ps02/ps02.ipynb) по [курсу](http://math-info.hse.ru/s17/1) «Введение в программирование» (Магистерская программа «Журналистика данных», НИУ ВШЭ, 2017-18).*

# %% [markdown]
# ## Задание 1 (1 балл)
#
# Вводится целое число X. Повторите его X раз и возведите полученное число в квадрат. Напечатайте получившееся.
#
# **Формат ввода**
#
# Целое число
#
# **Формат вывод**
#
# Ответ на задачу
#
# Примеры
#
# Ввод:
# 2
#
# Вывод:
# 484

# %%
X = input() # вводится целое число X

print(X*int(X))  # "повторить" строку можно оператором * (важно, что умножать мы все равно должны на целое число)

print(int((X*int(X)))**2) # наш итог
# Out:
# 2
# 22
# 484

# %% [markdown]
# ## Задание 2 (1.5 балла)
#
# В среднем за неделю Питон получает пять сообщений от Анаконды ($\lambda = 5$). Пользователь с клавиатуры вводит число сообщений, которые Анаконда может прислать Питону (число $k$). Напишите программу, которая выводит на экран вероятность, с которой Питон получит $k$ сообщений от Анаконды за неделю, с точностью до *трёх* знаков после запятой. Сообщение, выводимое на экран, должно быть таким (вместо выражений в квадратных скобках подставляются значения):
#
#     Число сообщений от Анаконды за неделю равно [k], вероятность равна [значение].
#
# Вероятность того, что Питон получит ровно $k$ сообщений, определяется следующим образом (распределение Пуассона):
#
# $$P(X = k) = e^{-\lambda}\cdot \frac{\lambda^k}{k!},$$ где $k!$ – «ка факториал», произведение всех целых чисел от 1 до $k$ включительно.
#
# **Подсказка:** функцию для вычисления факториала можно вызвать из модуля `math` (`factorial()`).
#
# **Пример:**
#
# *Входные данные*
#
#     Введите число сообщений: 2
#
# *Выходные данные*
#
#     Число сообщений от Анаконды за неделю равно 2, вероятность равна 0.084.

# %%
from math import exp, factorial # нужные функции 

k = int(input()) # кол-во сообщений
lamb = 5 # дано в условии

p = exp(-lamb)*(lamb**k / factorial(k))

print(f'Число сообщений от Анаконды за неделю равно {k}, вероятность равна {p}') # здесь все ок, но p слишко длинное
print(f'Число сообщений от Анаконды за неделю равно {k}, вероятность равна {p:.3f}') # такая запись также корректна
# Out:
# 2
# Число сообщений от Анаконды за неделю равно 2, вероятность равна 0.08422433748856833
# Число сообщений от Анаконды за неделю равно 2, вероятность равна 0.084

# %% [markdown]
# ## Задание 3 (1 балл)
#
# Дано целое число $n$. Выведите следующее за ним четное число. При решении этой задачи нельзя использовать условный оператор `if` и циклы.
#
# **Подсказка.** Бывает оператор целочисленного деления `//` и взятия остатка при делении `%`. Например, результат выполнения операции `15 % 7` равен `1`.
#
# **Примеры**
#
# _Входные данные_
#
#     7
#
# _Выходные данные_
#
#     8
#
# _Входные данные_
#
#     8
#
# _Выходные данные_
#
#     10

# %%
n = int(input()) # наше число
print((n//2 + 1)*2) # например, вот так (но это не единственный возможный вариант)
# Out:
# 4
# 6

# %% [markdown]
# ## Задание 4 (1.5 балла)
#
# Электронные часы показывают время в формате h:mm:ss, то есть сначала записывается количество часов (в 24-часовом формате), потом обязательно двузначное количество минут, затем обязательно двузначное количество секунд. Количество минут и секунд при необходимости дополняются до двузначного числа нулями.
#
# С начала суток прошло n секунд. Выведите, что покажут часы.
#
# Запрещается пользоваться условным оператором, циклами и любыми библиотеками.
#
# **Входные данные**
#
# Вводится целое число $n$.
#
# **Выходные данные**
#
# Выведите ответ на задачу, соблюдая требуемый формат.
#
# **Примеры**
#
# _Входные данные_
#
#     3602
#
# _Выходные данные_
#
#     1:00:02
#
# _Входные данные_
#
#     129700
#
# _Выходные данные_
#
#     12:01:40

# %%
n = int(input("Введите число секунд: "))
h = n // 3600 % 24
m = (n - h * 3600) // 60 % 60
s = (n - h * 3600 - m * 60) % 3600
print(f'{h}:{m:02d}:{s:02d}')
# Out:
# Введите число секунд: 129700
# 12:01:40

# %%
# пояснение к 02d

print('No digits: {:02d}, 1 digit: {:02d}, 2: {:02d}, 3: {:02d}'.format(0, 7, 42, 151))

# 2 говорит нам, что должно быть минимум 2 числа 
# d говорит, что речь идет о числах digit 
# если хотя бы двух чисел у нас не набирается, то слева будет ставиться 0
# Out:
# No digits: 00, 1 digit: 07, 2: 42, 3: 151

# %%
# если бы вдруг мы могли пользоваться библиотеками, то вот самая полезная:
import datetime
print(str(datetime.timedelta(seconds=3602)))
print(str(datetime.timedelta(seconds=129700)))
# Out:
# 1:00:02
# 1 day, 12:01:40

# %% [markdown]
# ## Задание 5 (1.5 балла)
#
# Дан список станций желтой ветки московского метро (упорядочены как на карте):
#
#     line = ["Третьяковская", "Марксистская", "Площадь Ильича", "Авиамоторная", "Шоссе Энтузиастов",
#     "Перово", "Новогиреево", "Новокосино"]
#
# Давайте считать, что движение происходит от Третьяковской до Новокосино.
#
# Напишите программу, которая запрашивает у пользователя название текущей станции метро (без лишнего пробела на конце) и выводит на экран сообщение вида
#
#     Следующая станция: станция.
#
# Считайте, что пользователь знает, какая станция конечная, и не будет запрашивать станцию, следующую после Новокосино.
#
# **Пример:**
#
# *Входные данные:*
#
#     Введите текущую станцию: Площадь Ильича
#
# *Выходные данные:*
#
#     Следующая станция: Авиамоторная
#
# **Подсказка:**
#
# Чтобы вернуть индекс определенного элемента в списке, нужно воспользоваться методом `.index()`.

# %%
line = ["Третьяковская", "Марксистская", "Площадь Ильича", "Авиамоторная", "Шоссе Энтузиастов",
"Перово", "Новогиреево", "Новокосино"]

station = input('Введите текущую станцию:')
print(line.index(station)) # индекс нашей станции в списке, значит следующая станция будет с этим индексом + 1

ind = line.index(station) + 1

print(f'Следующая станция: {line[ind]}')
# Out:
# Введите текущую станцию:Площадь Ильича
# 2
# Следующая станция: Авиамоторная

# %% [markdown]
# ## Задание 6 (1 балл)
# Распечатайте таблицу умножения от 1 до N для введенного числа M.
#
#
# **ФОРМАТ ВВОДА:**
#
# + Вводятся два целых положительных числа M и N, каждое с новой строки.
#
# **ФОРМАТ ВЫВОДА:**
#
# + Результаты умножения числа M на все числа от 1 до N включительно.
# + Каждое число выводится на новой строке.

# %%
M = int(input("Первое число: "))
N = int(input("Второе число: "))
for i in range(1, N+1): # если до N включительно, то добавляем +1
    print(M*i)
# Out:
# Первое число: 3
# Второе число: 7
# 3
# 6
# 9
# 12
# 15
# 18
# 21

# %% [markdown]
# ## Задание 7 (2.5 балла)
# Числа Фибоначчии — это последовательность чисел, заданная следующим образом:
#
# $$a_1 = 1,\quad a_2 = 1, \quad a_{k+1}=a_k+a_{k-1}$$
#
# Ввести число `k` с клавиатуры и вывести $a_k$. Считать, что число `k` всегда больше одного. (То есть на вход никогда не будет подано число, меньшее или равное одного.)
#
#
# **Пример.**
#
#
# _Входные данные:_
#
#     3
#
# _Выходные данные:_
#
#     2
#
# _Входные данные:_
#
#     5
#
# _Выходные данные:_
#
#     5
#
# _Входные данные:_
#
#     6
#
# _Выходные данные:_
#
#     8

# %%
a1 = a2 = 1 # дано

k = int(input("Введите целое число больше 1: "))

for i in range(k - 2):
    a1, a2 = a2, a1 + a2 # одновременное перезаписываем a1 и a2 до тех пор, пока не дойдем до конца
print(a2)
# Out:
# Введите целое число больше 1: 4
# 3
